# %%
import pandas as pd
import numpy as np

# %%
# Load data from file (for demonstration)
df = pd.read_csv("./test.csv")
print("Data loaded successfully!")
print(f"Shape: {df.shape}")
df.head()
# Out:
# Data loaded successfully!
# Shape: (20, 10)
#                    timestamp     open     high     low    close  volume  \
# 0  2021-01-01 15:10:00+05:30  1262.00  1262.15  1260.9  1260.90   763.0
# 1  2021-01-01 15:11:00+05:30  1260.90  1262.00  1259.6  1259.80  4316.0
# 2  2021-01-01 15:12:00+05:30  1259.80  1262.00  1258.4  1260.95  2131.0
# 3  2021-01-01 15:13:00+05:30  1260.95  1260.95  1260.5  1260.50   393.0
# 4  2021-01-01 15:14:00+05:30  1260.50  1260.90  1260.0  1260.70   742.0
#
#   stock_name  rolling_avg_10  volume_sum_10  target
# 0   AARTIIND        1262.040         9991.0       0
# 1   AARTIIND        1261.920        13187.0       1
# 2   AARTIIND        1261.815        14165.0       1
# 3   AARTIIND        1261.665        14117.0       1
# 4   AARTIIND        1261.390        13663.0       0
